# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Fig. 5 from Hong, et al. 2016

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st

mu = 0
sigma = 0.3
N = 1000

y = np.random.normal(mu, sigma, N)
plt.hist(y)
# Out:
# (array([  4.,  34.,  84., 164., 216., 212., 170.,  83.,  23.,  10.]),
#  array([-0.89349249, -0.71260024, -0.531708  , -0.35081575, -0.16992351,
#          0.01096874,  0.19186098,  0.37275323,  0.55364547,  0.73453772,
#          0.91542996]),
#  <a list of 10 Patch objects>)

# %%
# plot histogram for a given number of bins (using trapz to approximate pdf)
nbins = 100
counts, edges = np.histogram(y, bins=nbins)
xaxis = (edges[1:] + edges[:-1])/2
n_pdf = np.divide(counts, np.trapz(counts, xaxis))
plt.bar(xaxis, n_pdf)

# Show theoretical pdf in red
plt.plot(xaxis, st.norm.pdf(xaxis, mu, sigma), 'r-', linewidth=2)

# labels, ets
plt.title(f'Gaussian pdf, mu={mu:.2f}, sigma={sigma:.2f}')
plt.xlabel('Value')
plt.ylabel('Probability')
plt.legend(['Simulated', 'Theoretical'])
plt.show()
